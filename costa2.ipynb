# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale = 2.2)
plt.style.use('seaborn')

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import StratifiedKFold, train_test_split, ShuffleSplit
from sklearn.metrics import f1_score
import itertools
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBClassifier
import shap
from tqdm import tqdm
import featuretools as ft
import warnings
warnings.filterwarnings('ignore')
import time
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
df_train = pd.read_csv("../input/costa-rican-household-poverty-prediction/train.csv")
df_test = pd.read_csv("../input/costa-rican-household-poverty-prediction/test.csv")

# %%
print('df_train shape:', df_train.shape, '   ', 'df_test shape:', df_test.shape)
# Out:
# df_train shape: (9557, 143)     df_test shape: (23856, 142)

# %%
df_train.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
#    SQBovercrowding  SQBdependency  SQBmeaned  agesq  Target
# 0         1.000000            0.0      100.0   1849       4
# 1         1.000000           64.0      144.0   4489       4
# 2         0.250000           64.0      121.0   8464       4
# 3         1.777778            1.0      121.0    289       4
# 4         1.777778            1.0      121.0   1369       4
#
# [5 rows x 143 columns]

# %%
df_test.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1  ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2  ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3  ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4  ID_a62966799  175000.0       0      4       0     1       1     1    1.0
#
#    r4h1  ...  age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0     1  ...    4            0      16               9          0
# 1     1  ...   41          256    1681               9          0
# 2     1  ...   41          289    1681               9          0
# 3     0  ...   59          256    3481               1        256
# 4     0  ...   18          121     324               1          0
#
#    SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# 0             1             2.25           0.25     272.25     16
# 1             1             2.25           0.25     272.25   1681
# 2             1             2.25           0.25     272.25   1681
# 3             0             1.00           0.00     256.00   3481
# 4             1             0.25          64.00        NaN    324
#
# [5 rows x 142 columns]

# %%
description = [
("v2a1"," Monthly rent payment"),
("hacdor"," =1 Overcrowding by bedrooms"),
("rooms","  number of all rooms in the house"),
("hacapo"," =1 Overcrowding by rooms"),
("v14a"," =1 has toilet in the household"),
("refrig"," =1 if the household has refrigerator"),
("v18q"," owns a tablet"),
("v18q1"," number of tablets household owns"),
("r4h1"," Males younger than 12 years of age"),
("r4h2"," Males 12 years of age and older"),
("r4h3"," Total males in the household"),
("r4m1"," Females younger than 12 years of age"),
("r4m2"," Females 12 years of age and older"),
("r4m3"," Total females in the household"),
("r4t1"," persons younger than 12 years of age"),
("r4t2"," persons 12 years of age and older"),
("r4t3"," Total persons in the household"),
("tamhog"," size of the household"),
("tamviv"," number of persons living in the household"),
("escolari"," years of schooling"),
("rez_esc"," Years behind in school"),
("hhsize"," household size"),
("paredblolad"," =1 if predominant material on the outside wall is block or brick"),
("paredzocalo"," =1 if predominant material on the outside wall is socket (wood, zinc or absbesto"),
("paredpreb"," =1 if predominant material on the outside wall is prefabricated or cement"),
("pareddes"," =1 if predominant material on the outside wall is waste material"),
("paredmad"," =1 if predominant material on the outside wall is wood"),
("paredzinc"," =1 if predominant material on the outside wall is zink"),
("paredfibras"," =1 if predominant material on the outside wall is natural fibers"),
("paredother"," =1 if predominant material on the outside wall is other"),
("pisomoscer"," =1 if predominant material on the floor is mosaic ceramic   terrazo"),
("pisocemento"," =1 if predominant material on the floor is cement"),
("pisoother"," =1 if predominant material on the floor is other"),
("pisonatur"," =1 if predominant material on the floor is  natural material"),
("pisonotiene"," =1 if no floor at the household"),
("pisomadera"," =1 if predominant material on the floor is wood"),
("techozinc"," =1 if predominant material on the roof is metal foil or zink"),
("techoentrepiso"," =1 if predominant material on the roof is fiber cement,   mezzanine "),
("techocane"," =1 if predominant material on the roof is natural fibers"),
("techootro"," =1 if predominant material on the roof is other"),
("cielorazo"," =1 if the house has ceiling"),
("abastaguadentro"," =1 if water provision inside the dwelling"),
("abastaguafuera"," =1 if water provision outside the dwelling"),
("abastaguano"," =1 if no water provision"),
("public"," =1 electricity from CNFL,  ICE, ESPH/JASEC"),
("planpri"," =1 electricity from private plant"),
("noelec"," =1 no electricity in the dwelling"),
("coopele"," =1 electricity from cooperative"),
("sanitario1"," =1 no toilet in the dwelling"),
("sanitario2"," =1 toilet connected to sewer or cesspool"),
("sanitario3"," =1 toilet connected to  septic tank"),
("sanitario5"," =1 toilet connected to black hole or letrine"),
("sanitario6"," =1 toilet connected to other system"),
("energcocinar1"," =1 no main source of energy used for cooking (no kitchen)"),
("energcocinar2"," =1 main source of energy used for cooking electricity"),
("energcocinar3"," =1 main source of energy used for cooking gas"),
("energcocinar4"," =1 main source of energy used for cooking wood charcoal"),
("elimbasu1"," =1 if rubbish disposal mainly by tanker truck"),
("elimbasu2"," =1 if rubbish disposal mainly by botan hollow or buried"),
("elimbasu3"," =1 if rubbish disposal mainly by burning"),
("elimbasu4"," =1 if rubbish disposal mainly by throwing in an unoccupied space"),
("elimbasu5"," =1 if rubbish disposal mainly by throwing in river,   creek or sea"),
("elimbasu6"," =1 if rubbish disposal mainly other"),
("epared1"," =1 if walls are bad"),
("epared2"," =1 if walls are regular"),
("epared3"," =1 if walls are good"),
("etecho1"," =1 if roof are bad"),
("etecho2"," =1 if roof are regular"),
("etecho3"," =1 if roof are good"),
("eviv1"," =1 if floor are bad"),
("eviv2"," =1 if floor are regular"),
("eviv3"," =1 if floor are good"),
("dis"," =1 if disable person"),
("male"," =1 if male"),
("female"," =1 if female"),
("estadocivil1"," =1 if less than 10 years old"),
("estadocivil2"," =1 if free or coupled uunion"),
("estadocivil3"," =1 if married"),
("estadocivil4"," =1 if divorced"),
("estadocivil5"," =1 if separated"),
("estadocivil6"," =1 if widow/er"),
("estadocivil7"," =1 if single"),
("parentesco1"," =1 if household head"),
("parentesco2"," =1 if spouse/partner"),
("parentesco3"," =1 if son/doughter"),
("parentesco4"," =1 if stepson/doughter"),
("parentesco5"," =1 if son/doughter in law"),
("parentesco6"," =1 if grandson/doughter"),
("parentesco7"," =1 if mother/father"),
("parentesco8"," =1 if father/mother in law"),
("parentesco9"," =1 if brother/sister"),
("parentesco10"," =1 if brother/sister in law"),
("parentesco11"," =1 if other family member"),
("parentesco12"," =1 if other non family member"),
("idhogar"," Household level identifier"),
("hogar_nin"," Number of children 0 to 19 in household"),
("hogar_adul"," Number of adults in household"),
("hogar_mayor"," # of individuals 65+ in the household"),
("hogar_total"," # of total individuals in the household"),
("dependency"," Dependency rate"),
("edjefe"," years of education of male head of household"),
("edjefa"," years of education of female head of household"),
("meaneduc","average years of education for adults (18+)"),
("instlevel1"," =1 no level of education"),
("instlevel2"," =1 incomplete primary"),
("instlevel3"," =1 complete primary"),
("instlevel4"," =1 incomplete academic secondary level"),
("instlevel5"," =1 complete academic secondary level"),
("instlevel6"," =1 incomplete technical secondary level"),
("instlevel7"," =1 complete technical secondary level"),
("instlevel8"," =1 undergraduate and higher education"),
("instlevel9"," =1 postgraduate higher education"),
("bedrooms"," number of bedrooms"),
("overcrowding"," # persons per room"),
("tipovivi1"," =1 own and fully paid house"),
("tipovivi2"," =1 own,   paying in installments"),
("tipovivi3"," =1 rented"),
("tipovivi4"," =1 precarious"),
("tipovivi5"," =1 other(assigned"),
("computer"," =1 if the household has notebook or desktop computer,   borrowed)"),
("television"," =1 if the household has TV"),
("mobilephone"," =1 if mobile phone"),
("qmobilephone"," # of mobile phones"),
("lugar1"," =1 region Central"),
("lugar2"," =1 region Chorotega"),
("lugar3"," =1 region PacÃƒÂ­fico central"),
("lugar4"," =1 region Brunca"),
("lugar5"," =1 region Huetar AtlÃƒÂ¡ntica"),
("lugar6"," =1 region Huetar Norte"),
("area1"," =1 zona urbana"),
("area2"," =2 zona rural"),
("age"," Age in years"),
("SQBescolari"," escolari squared"),
("SQBage"," age squared"),
("SQBhogar_total"," hogar_total squared"),
("SQBedjefe"," edjefe squared"),
("SQBhogar_nin"," hogar_nin squared"),
("SQBovercrowding"," overcrowding squared"),
("SQBdependency"," dependency squared"),
("SQBmeaned"," meaned squared"),
("agesq"," Age squared"),]

description = pd.DataFrame(description, columns=['varname', 'description'])

# %%
total = df_train.isnull().sum().sort_values(ascending = False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending = False)
missing_df = pd.concat([total, percent], axis = 1, keys = ['total', 'percent'])

missing_df.head(20)
# Out:
#               total    percent
# rez_esc        7928  82.954902
# v18q1          7342  76.823271
# v2a1           6860  71.779847
# SQBmeaned         5   0.052318
# meaneduc          5   0.052318
# Id                0   0.000000
# hogar_adul        0   0.000000
# parentesco10      0   0.000000
# parentesco11      0   0.000000
# parentesco12      0   0.000000
# idhogar           0   0.000000
# hogar_nin         0   0.000000
# dependency        0   0.000000
# hogar_mayor       0   0.000000
# hogar_total       0   0.000000
# edjefe            0   0.000000
# edjefa            0   0.000000
# instlevel1        0   0.000000
# instlevel2        0   0.000000
# parentesco9       0   0.000000

# %%
df_train.loc[(df_train['edjefa'] == "yes") & (df_train['parentesco1'] == 1), "edjefa"] = df_train.loc[(df_train['edjefa'] == "yes") & (df_train['parentesco1'] == 1), "escolari"]
df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefe'] = df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']

df_test.loc[(df_test['edjefa'] == "yes") & (df_test['parentesco1'] == 1), "edjefa"] = df_test.loc[(df_test['edjefa'] == "yes") & (df_test['parentesco1'] == 1), "escolari"]
df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefe'] = df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']

df_train.loc[df_train['edjefa'] == 'yes', 'edjefa'] = 4
df_train.loc[df_train['edjefe'] == 'yes', 'edjefe'] = 4

df_test.loc[df_test['edjefa'] == 'yes', 'edjefa'] = 4
df_test.loc[df_test['edjefe'] == 'yes', 'edjefe'] = 4

df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis = 1)
df_test['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis = 1)

df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'v14a'] = 0
df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'sanitario1'] = 0

df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'v14a'] = 0
df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'sanitario1'] = 0

# %%
df_train['rez_esc'].fillna(0, inplace = True)
df_test['rez_esc'].fillna(0, inplace = True)

# %%
df_train['SQBmeaned'].fillna(0, inplace = True)
df_test['SQBmeaned'].fillna(0, inplace = True)

# %%
df_train['meaneduc'].fillna(0, inplace = True)
df_test['meaneduc'].fillna(0, inplace = True)

# %%
df_train['v18q'].value_counts()
# Out:
# 0    7342
# 1    2215
# Name: v18q, dtype: int64

# %%
df_train.loc[df_train['v18q'] == 1, 'v18q1'].value_counts()
# Out:
# 1.0    1586
# 2.0     444
# 3.0     129
# 4.0      37
# 5.0      13
# 6.0       6
# Name: v18q1, dtype: int64

# %%
df_train.loc[df_train['v18q']==0, 'v18q1'].value_counts()
# Out:
# Series([], Name: v18q1, dtype: int64)

# %%
df_train['v18q1'].fillna(0, inplace = True)
df_test['v18q1'].fillna(0, inplace = True)

# %%
df_train['tipovivi3'].value_counts()
# Out:
# 0    7821
# 1    1736
# Name: tipovivi3, dtype: int64

# %%
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 1, 'v2a1'], label = 'Monthly rent payment of household(rented = 1)')
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 0, 'v2a1'], label = 'Monthly rent payment of household(rented = 0)')
plt.xscale('log')
plt.legend()
plt.show()

# %%
df_train['v2a1'].fillna(0, inplace = True)
df_test['v2a1'].fillna(0, inplace = True)

# %%
total = df_train.isnull().sum().sort_values(ascending = False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending = False)
missing_df = pd.concat([total, percent], axis = 1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#               Total  Percent
# edjef          9557    100.0
# v2a1              0      0.0
# parentesco10      0      0.0
# parentesco11      0      0.0
# parentesco12      0      0.0
# idhogar           0      0.0
# hogar_nin         0      0.0
# hogar_adul        0      0.0
# hogar_mayor       0      0.0
# hogar_total       0      0.0
# dependency        0      0.0
# edjefe            0      0.0
# edjefa            0      0.0
# meaneduc          0      0.0
# instlevel1        0      0.0
# instlevel2        0      0.0
# instlevel3        0      0.0
# parentesco9       0      0.0
# parentesco8       0      0.0
# parentesco7       0      0.0

# %%
total = df_test.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_test.isnull().sum() / df_test.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#               Total  Percent
# edjef         23856    100.0
# hogar_mayor       0      0.0
# parentesco10      0      0.0
# parentesco11      0      0.0
# parentesco12      0      0.0
# idhogar           0      0.0
# hogar_nin         0      0.0
# hogar_adul        0      0.0
# hogar_total       0      0.0
# parentesco8       0      0.0
# dependency        0      0.0
# edjefe            0      0.0
# edjefa            0      0.0
# meaneduc          0      0.0
# instlevel1        0      0.0
# instlevel2        0      0.0
# parentesco9       0      0.0
# parentesco7       0      0.0
# instlevel4        0      0.0
# estadocivil5      0      0.0

# %%
features_object = [col for col in df_train.columns if df_train[col].dtype == 'object']

# %%
features_object
# Out:
# ['Id', 'idhogar', 'dependency', 'edjefe', 'edjefa']

# %%
df_train['dependency'] = np.sqrt(df_train['SQBdependency'])
df_test['dependency'] = np.sqrt(df_test['SQBdependency'])

# %%
def replace_edjefe(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefe'] = df_train['edjefe'].apply(replace_edjefe).astype(float)
df_test['edjefe'] = df_test['edjefe'].apply(replace_edjefe).astype(float)

# %%
def replace_edjefa(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefa'] = df_train['edjefa'].apply(replace_edjefa).astype(float)
df_test['edjefa'] = df_test['edjefa'].apply(replace_edjefa).astype(float)

# %%
df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis = 1)
df_test['edjef'] = np.max(df_test[['edjefa', 'edjefe']], axis = 1)

# %%
np.max(df_train[['edjefa', 'edjefe']], axis = 1)
# Out:
# 0       10.0
# 1       12.0
# 2       11.0
# 3       11.0
# 4       11.0
#         ...
# 9552     9.0
# 9553     9.0
# 9554     9.0
# 9555     9.0
# 9556     9.0
# Length: 9557, dtype: float64

# %%
df_train['roof_waste_material'] = np.nan
df_test['roof_waste_material'] = np.nan
df_train['electricity_other'] = np.nan
df_test['electricity_other'] = np.nan

# %%
def fill_roof_exception(x):
    if (x['techozinc'] == 0) and (x['techoentrepiso'] == 0) and (x['techocane'] == 0) and (x['techootro'] == 0):
        return 1
    else:
        return 0

def fill_no_electricity(x):
    if (x['public'] == 0) and (x['planpri'] == 0) and (x['noelec'] == 0) and (x['coopele'] == 0):
        return 1
    else:
        return 0

df_train['roof_waste_material'] = df_train.apply(lambda x:fill_roof_exception(x), axis = 1)
df_test['roof_waste_material'] = df_test.apply(lambda x:fill_roof_exception(x), axis = 1)
df_train['electricity_other'] = df_train.apply(lambda x:fill_no_electricity(x), axis = 1)
df_test['electricity_other'] = df_test.apply(lambda x:fill_no_electricity(x), axis = 1)

# %%
binary_cat_features = [col for col in df_train.columns if df_train[col].value_counts().shape[0] == 2]

# %%
continuous_features = [col for col in df_train.columns if col not in binary_cat_features]
continuous_features = [col for col in continuous_features if col not in features_object]
continuous_features = [col for col in continuous_features if col not in ['Id', 'Target', 'idhogar']]

# %%
print('There are {} continuous features'.format(len(continuous_features)))
for col in continuous_features:
    print('{}: {}'.format(col, description.loc[description['varname'] == col, 'description'].values))
# Out:
# There are 37 continuous features
# v2a1: [' Monthly rent payment']
# rooms: ['  number of all rooms in the house']
# v18q1: [' number of tablets household owns']
# r4h1: [' Males younger than 12 years of age']
# r4h2: [' Males 12 years of age and older']
# r4h3: [' Total males in the household']
# r4m1: [' Females younger than 12 years of age']
# r4m2: [' Females 12 years of age and older']
# r4m3: [' Total females in the household']
# r4t1: [' persons younger than 12 years of age']
# r4t2: [' persons 12 years of age and older']
# r4t3: [' Total persons in the household']
# tamhog: [' size of the household']
# tamviv: [' number of persons living in the household']
# escolari: [' years of schooling']
# rez_esc: [' Years behind in school']
# hhsize: [' household size']
# elimbasu5: [' =1 if rubbish disposal mainly by throwing in river,   creek or sea']
# hogar_nin: [' Number of children 0 to 19 in household']
# hogar_adul: [' Number of adults in household']
# hogar_mayor: [' # of individuals 65+ in the household']
# hogar_total: [' # of total individuals in the household']
# meaneduc: ['average years of education for adults (18+)']
# bedrooms: [' number of bedrooms']
# overcrowding: [' # persons per room']
# qmobilephone: [' # of mobile phones']
# age: [' Age in years']
# SQBescolari: [' escolari squared']
# SQBage: [' age squared']
# SQBhogar_total: [' hogar_total squared']
# SQBedjefe: [' edjefe squared']
# SQBhogar_nin: [' hogar_nin squared']
# SQBovercrowding: [' overcrowding squared']
# SQBdependency: [' dependency squared']
# SQBmeaned: [' meaned squared']
# agesq: [' Age squared']
# edjef: []

# %%
df_train.drop('tamhog', axis = 1, inplace = True)
df_test.drop('tamhog', axis = 1, inplace = True)

# %%
df_train['adult'] = df_train['hogar_adul'] - df_train['hogar_mayor']
df_train['dependency_count'] = df_train['hogar_nin'] + df_train['hogar_mayor']
df_train['dependency'] = df_train['dependency_count'] / df_train['adult']
df_train['child_percent'] = df_train['hogar_nin'] / df_train['hogar_total']
df_train['elder_percent'] = df_train['hogar_mayor'] / df_train['hogar_total']
df_train['adult_percent'] = df_train['hogar_adul'] / df_train['hogar_total']
df_train['males_younger_12_years_percent'] = df_train['r4h1'] / df_train['hogar_total']
df_train['males_older_12_years_percent'] = df_train['r4h2'] / df_train['hogar_total']
df_train['males_percent'] = df_train['r4h3'] / df_train['hogar_total']
df_train['females_younger_12_years_percent'] = df_train['r4m1'] / df_train['hogar_total']
df_train['females_older_12_years_percent'] = df_train['r4m2'] / df_train['hogar_total']
df_train['females_percent'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_percent'] = df_train['r4t1'] / df_train['hogar_total']
df_train['persons_older_12_years_percent'] = df_train['r4t2'] / df_train['hogar_total']
df_train['persons_percent'] = df_train['r4t3'] / df_train['hogar_total']

# %%
df_test['adult'] = df_test['hogar_adul'] - df_test['hogar_mayor']
df_test['dependency_count'] = df_test['hogar_nin'] + df_test['hogar_mayor']
df_test['dependency'] = df_test['dependency_count'] / df_test['adult']
df_test['child_percent'] = df_test['hogar_nin'] / df_test['hogar_total']
df_test['elder_percent'] = df_test['hogar_mayor'] / df_test['hogar_total']
df_test['adult_percent'] = df_test['hogar_adul'] / df_test['hogar_total']
df_test['males_younger_12_years_percent'] = df_test['r4h1'] / df_test['hogar_total']
df_test['males_older_12_years_percent'] = df_test['r4h2'] / df_test['hogar_total']
df_test['males_percent'] = df_test['r4h3'] / df_test['hogar_total']
df_test['females_younger_12_years_percent'] = df_test['r4m1'] / df_test['hogar_total']
df_test['females_older_12_years_percent'] = df_test['r4m2'] / df_test['hogar_total']
df_test['females_percent'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_percent'] = df_test['r4t1'] / df_test['hogar_total']
df_test['persons_older_12_years_percent'] = df_test['r4t2'] / df_test['hogar_total']
df_test['persons_percent'] = df_test['r4t3'] / df_test['hogar_total']

# %%
df_train['males_younger_12_years_in_household_size'] = df_train['r4h1'] / df_train['hhsize']
df_train['males_older_12_years_in_household_size'] = df_train['r4h2'] / df_train['hhsize']
df_train['males_in_household_size'] = df_train['r4h3'] / df_train['hhsize']
df_train['females_younger_12_years_in_household_size'] = df_train['r4m1'] / df_train['hhsize']
df_train['females_older_12_years_in_household_size'] = df_train['r4m2'] / df_train['hhsize']
df_train['females_in_household_size'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_in_household_size'] = df_train['r4t1'] / df_train['hhsize']
df_train['persons_older_12_years_in_household_size'] = df_train['r4t2'] / df_train['hhsize']
df_train['persons_in_household_size'] = df_train['r4t3'] / df_train['hhsize']

# %%
df_test['males_younger_12_years_in_household_size'] = df_test['r4h1'] / df_test['hhsize']
df_test['males_older_12_years_in_household_size'] = df_test['r4h2'] / df_test['hhsize']
df_test['males_in_household_size'] = df_test['r4h3'] / df_test['hhsize']
df_test['females_younger_12_years_in_household_size'] = df_test['r4m1'] / df_test['hhsize']
df_test['females_older_12_years_in_household_size'] = df_test['r4m2'] / df_test['hhsize']
df_test['females_in_household_size'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_in_household_size'] = df_test['r4t1'] / df_test['hhsize']
df_test['persons_older_12_years_in_household_size'] = df_test['r4t2'] / df_test['hhsize']
df_test['persons_in_household_size'] = df_test['r4t3'] / df_test['hhsize']

# %%
df_train['overcrowding_room_and_bedroom'] = (df_train['hacdor'] + df_train['hacapo'])/2
df_test['overcrowding_room_and_bedroom'] = (df_test['hacdor'] + df_test['hacapo'])/2

# %%
df_train['escolari_age'] = df_train['escolari']/df_train['age']
df_test['escolari_age'] = df_test['escolari']/df_test['age']

df_train['age_12_19'] = df_train['hogar_nin'] - df_train['r4t1']
df_test['age_12_19'] = df_test['hogar_nin'] - df_test['r4t1']

# %%
df_train['phones-per-capita'] = df_train['qmobilephone'] / df_train['tamviv']
df_train['tablets-per-capita'] = df_train['v18q1'] / df_train['tamviv']
df_train['rooms-per-capita'] = df_train['rooms'] / df_train['tamviv']
df_train['rent-per-capita'] = df_train['v2a1'] / df_train['tamviv']

# %%
df_test['phones-per-capita'] = df_test['qmobilephone'] / df_test['tamviv']
df_test['tablets-per-capita'] = df_test['v18q1'] / df_test['tamviv']
df_test['rooms-per-capita'] = df_test['rooms'] / df_test['tamviv']
df_test['rent-per-capita'] = df_test['v2a1'] / df_test['tamviv']

# %%
(df_train['hogar_total'] == df_train['r4t3']).sum()
# Out:
# 9509

# %%
family_size_features = ['adult', 'hogar_adul', 'hogar_mayor', 'hogar_nin', 'hogar_total', 'r4h1' ,'r4h2', 'r4h3', 'r4m1', 'r4m2', 'r4m3', 'r4t1', 'r4t2', 'r4t3', 'hhsize']
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v2a1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v2a1'] / df_train[col]
    df_test[new_col_name] = df_test['v2a1'] / df_test[col]

# %%
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rooms'] / df_train[col]
    df_test[new_col_name] = df_test['rooms'] / df_test[col]
    
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
new_feats = []

for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('bedrooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['bedrooms'] / df_train[col]
    df_test[new_col_name] = df_test['bedrooms'] / df_test[col]
    
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 220) (23856, 219)

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v18q1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v18q1'] / df_train[col]
    df_test[new_col_name] = df_test['v18q1'] / df_test[col]
    
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('qmobilephone', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['qmobilephone'] / df_train[col]
    df_test[new_col_name] = df_test['qmobilephone'] / df_test[col]
    
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rez_esc', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rez_esc'] / df_train[col]
    df_test[new_col_name] = df_test['rez_esc'] / df_test[col]
    
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace = True)
    df_train[col].fillna(0, inplace = True)
    
    df_test[col].replace([np.inf], np.nan, inplace = True)
    df_test[col].fillna(0, inplace = True)

# %%
df_train['rez_esc_age'] = df_train['rez_esc'] / df_train['age']
df_train['rez_esc_escolari'] = df_train['rez_esc'] / df_train['escolari']

df_test['rez_esc_age'] = df_test['rez_esc'] / df_test['age']
df_test['rez_esc_escolari'] = df_test['rez_esc'] / df_test['escolari']

# %%
df_train['tabulet_x_qmobilephone'] = df_train['v18q1'] * df_train['qmobilephone']
df_test['tabulet_x_qmobilephone'] = df_test['v18q1'] * df_test['qmobilephone']

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
        
for col1 in ['etecho1', 'etecho2', 'etecho3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        for col3 in ['eviv1', 'eviv2', 'eviv3']:
            new_col_name = 'new_{}_x_{}_x{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_test[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 322) (23856, 321)

# %%
for col1 in ['public', 'planpri', 'noelec', 'coopele']:
    for col2 in ['energcocinar1', 'energcocinar2', 'energcocinar3', 'energcocinar4']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
    for col2 in ['elimbasu1', 'elimbasu2', 'elimbasu3', 'elimbasu4', 'elimbasu5', 'elimbasu6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['abastaguadentro', 'abastaguafuera', 'abastaguano']:
    for col2 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 383) (23856, 382)

# %%
for col1 in ['area1', 'area2']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 455) (23856, 454)

# %%
df_train['electronics'] = df_train['computer'] * df_train['mobilephone'] * df_train['television'] * df_train['v18q'] * df_train['refrig']
df_test['electronics'] = df_test['computer'] * df_test['mobilephone'] * df_test['television'] * df_test['v18q'] * df_test['refrig']

df_train['no_appliances'] = df_train['refrig'] + df_train['computer'] + df_train['television'] + df_train['mobilephone']
df_test['no_appliances'] = df_test['refrig'] + df_test['computer'] + df_test['television'] + df_test['mobilephone']

# %%
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
    for col1 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
        
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]        
        
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        for col3 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_train[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 733) (23856, 732)

# %%
cols_with_only_one_value = []
for col in df_train.columns:
    if col == 'Target':
        continue
    if df_train[col].value_counts().shape[0] == 1 or df_test[col].value_counts().shape[0] == 1:
        print(col)
        cols_with_only_one_value.append(col)
# Out:
# elimbasu5
# new_planpri_x_energcocinar1
# new_planpri_x_energcocinar2
# new_planpri_x_energcocinar3
# new_planpri_x_energcocinar4
# new_noelec_x_energcocinar2
# new_sanitario1_x_elimbasu4
# new_sanitario1_x_elimbasu5
# new_sanitario1_x_elimbasu6
# new_sanitario2_x_elimbasu4
# new_sanitario2_x_elimbasu5
# new_sanitario2_x_elimbasu6
# new_sanitario3_x_elimbasu5
# new_sanitario5_x_elimbasu4
# new_sanitario5_x_elimbasu5
# new_sanitario5_x_elimbasu6
# new_sanitario6_x_elimbasu2
# new_sanitario6_x_elimbasu4
# new_sanitario6_x_elimbasu5
# new_sanitario6_x_elimbasu6
# new_abastaguafuera_x_sanitario6
# new_abastaguano_x_sanitario2
# new_abastaguano_x_sanitario6
# new_paredblolad_x_pisonatur
# new_paredblolad_x_pisonotiene
# new_paredzocalo_x_pisoother
# new_paredzocalo_x_pisonatur
# new_paredpreb_x_pisonatur
# new_pareddes_x_pisoother
# new_pareddes_x_pisonatur
# new_paredmad_x_pisoother
# new_paredmad_x_pisonatur
# new_paredzinc_x_pisoother
# new_paredzinc_x_pisonatur
# new_paredfibras_x_pisoother
# new_paredfibras_x_pisonatur
# new_paredfibras_x_pisonotiene
# new_paredfibras_x_pisomadera
# new_paredother_x_pisoother
# new_paredother_x_pisonatur
# new_paredother_x_pisonotiene
# new_paredother_x_pisomadera
# new_techocane_x_pisomadera
# new_techootro_x_pisomadera
# new_paredzocalo_x_techoentrepiso
# new_paredzocalo_x_techocane
# new_paredzocalo_x_techootro
# new_paredpreb_x_techootro
# new_pareddes_x_techoentrepiso
# new_pareddes_x_techocane
# new_pareddes_x_techootro
# new_paredmad_x_techocane
# new_paredmad_x_techootro
# new_paredzinc_x_techoentrepiso
# new_paredzinc_x_techocane
# new_paredzinc_x_techootro
# new_paredfibras_x_techoentrepiso
# new_paredfibras_x_techootro
# new_paredother_x_techoentrepiso
# new_paredother_x_techocane
# new_paredother_x_techootro
# new_paredblolad_x_pisocemento_x_techocane
# new_paredblolad_x_pisocemento_x_techootro
# new_paredblolad_x_pisoother_x_techoentrepiso
# new_paredblolad_x_pisoother_x_techocane
# new_paredblolad_x_pisoother_x_techootro
# new_paredblolad_x_pisonatur_x_techozinc
# new_paredblolad_x_pisonatur_x_techoentrepiso
# new_paredblolad_x_pisonatur_x_techocane
# new_paredblolad_x_pisonatur_x_techootro
# new_paredblolad_x_pisonotiene_x_techozinc
# new_paredblolad_x_pisonotiene_x_techoentrepiso
# new_paredblolad_x_pisonotiene_x_techocane
# new_paredblolad_x_pisonotiene_x_techootro
# new_paredblolad_x_pisomadera_x_techocane
# new_paredblolad_x_pisomadera_x_techootro
# new_paredzocalo_x_pisomoscer_x_techoentrepiso
# new_paredzocalo_x_pisomoscer_x_techocane
# new_paredzocalo_x_pisomoscer_x_techootro
# new_paredzocalo_x_pisocemento_x_techoentrepiso
# new_paredzocalo_x_pisocemento_x_techocane
# new_paredzocalo_x_pisocemento_x_techootro
# new_paredzocalo_x_pisoother_x_techozinc
# new_paredzocalo_x_pisoother_x_techoentrepiso
# new_paredzocalo_x_pisoother_x_techocane
# new_paredzocalo_x_pisoother_x_techootro
# new_paredzocalo_x_pisonatur_x_techozinc
# new_paredzocalo_x_pisonatur_x_techoentrepiso
# new_paredzocalo_x_pisonatur_x_techocane
# new_paredzocalo_x_pisonatur_x_techootro
# new_paredzocalo_x_pisonotiene_x_techoentrepiso
# new_paredzocalo_x_pisonotiene_x_techocane
# new_paredzocalo_x_pisonotiene_x_techootro
# new_paredzocalo_x_pisomadera_x_techoentrepiso
# new_paredzocalo_x_pisomadera_x_techocane
# new_paredzocalo_x_pisomadera_x_techootro
# new_paredpreb_x_pisocemento_x_techoentrepiso
# new_paredpreb_x_pisocemento_x_techocane
# new_paredpreb_x_pisocemento_x_techootro
# new_paredpreb_x_pisoother_x_techoentrepiso
# new_paredpreb_x_pisoother_x_techocane
# new_paredpreb_x_pisoother_x_techootro
# new_paredpreb_x_pisonatur_x_techozinc
# new_paredpreb_x_pisonatur_x_techoentrepiso
# new_paredpreb_x_pisonatur_x_techocane
# new_paredpreb_x_pisonatur_x_techootro
# new_paredpreb_x_pisonotiene_x_techozinc
# new_paredpreb_x_pisonotiene_x_techoentrepiso
# new_paredpreb_x_pisonotiene_x_techocane
# new_paredpreb_x_pisonotiene_x_techootro
# new_paredpreb_x_pisomadera_x_techoentrepiso
# new_paredpreb_x_pisomadera_x_techocane
# new_paredpreb_x_pisomadera_x_techootro
# new_pareddes_x_pisomoscer_x_techozinc
# new_pareddes_x_pisomoscer_x_techoentrepiso
# new_pareddes_x_pisomoscer_x_techocane
# new_pareddes_x_pisomoscer_x_techootro
# new_pareddes_x_pisocemento_x_techoentrepiso
# new_pareddes_x_pisocemento_x_techocane
# new_pareddes_x_pisocemento_x_techootro
# new_pareddes_x_pisoother_x_techozinc
# new_pareddes_x_pisoother_x_techoentrepiso
# new_pareddes_x_pisoother_x_techocane
# new_pareddes_x_pisoother_x_techootro
# new_pareddes_x_pisonatur_x_techozinc
# new_pareddes_x_pisonatur_x_techoentrepiso
# new_pareddes_x_pisonatur_x_techocane
# new_pareddes_x_pisonatur_x_techootro
# new_pareddes_x_pisonotiene_x_techoentrepiso
# new_pareddes_x_pisonotiene_x_techocane
# new_pareddes_x_pisonotiene_x_techootro
# new_pareddes_x_pisomadera_x_techozinc
# new_pareddes_x_pisomadera_x_techoentrepiso
# new_pareddes_x_pisomadera_x_techocane
# new_pareddes_x_pisomadera_x_techootro
# new_paredmad_x_pisomoscer_x_techocane
# new_paredmad_x_pisomoscer_x_techootro
# new_paredmad_x_pisocemento_x_techoentrepiso
# new_paredmad_x_pisocemento_x_techocane
# new_paredmad_x_pisocemento_x_techootro
# new_paredmad_x_pisoother_x_techozinc
# new_paredmad_x_pisoother_x_techoentrepiso
# new_paredmad_x_pisoother_x_techocane
# new_paredmad_x_pisoother_x_techootro
# new_paredmad_x_pisonatur_x_techozinc
# new_paredmad_x_pisonatur_x_techoentrepiso
# new_paredmad_x_pisonatur_x_techocane
# new_paredmad_x_pisonatur_x_techootro
# new_paredmad_x_pisonotiene_x_techoentrepiso
# new_paredmad_x_pisonotiene_x_techocane
# new_paredmad_x_pisonotiene_x_techootro
# new_paredmad_x_pisomadera_x_techocane
# new_paredzinc_x_pisomoscer_x_techoentrepiso
# new_paredzinc_x_pisomoscer_x_techocane
# new_paredzinc_x_pisomoscer_x_techootro
# new_paredzinc_x_pisocemento_x_techoentrepiso
# new_paredzinc_x_pisocemento_x_techocane
# new_paredzinc_x_pisocemento_x_techootro
# new_paredzinc_x_pisoother_x_techozinc
# new_paredzinc_x_pisoother_x_techoentrepiso
# new_paredzinc_x_pisoother_x_techocane
# new_paredzinc_x_pisoother_x_techootro
# new_paredzinc_x_pisonatur_x_techozinc
# new_paredzinc_x_pisonatur_x_techoentrepiso
# new_paredzinc_x_pisonatur_x_techocane
# new_paredzinc_x_pisonatur_x_techootro
# new_paredzinc_x_pisonotiene_x_techoentrepiso
# new_paredzinc_x_pisonotiene_x_techocane
# new_paredzinc_x_pisonotiene_x_techootro
# new_paredzinc_x_pisomadera_x_techoentrepiso
# new_paredzinc_x_pisomadera_x_techocane
# new_paredzinc_x_pisomadera_x_techootro
# new_paredfibras_x_pisomoscer_x_techoentrepiso
# new_paredfibras_x_pisomoscer_x_techocane
# new_paredfibras_x_pisomoscer_x_techootro
# new_paredfibras_x_pisocemento_x_techoentrepiso
# new_paredfibras_x_pisocemento_x_techocane
# new_paredfibras_x_pisocemento_x_techootro
# new_paredfibras_x_pisoother_x_techozinc
# new_paredfibras_x_pisoother_x_techoentrepiso
# new_paredfibras_x_pisoother_x_techocane
# new_paredfibras_x_pisoother_x_techootro
# new_paredfibras_x_pisonatur_x_techozinc
# new_paredfibras_x_pisonatur_x_techoentrepiso
# new_paredfibras_x_pisonatur_x_techocane
# new_paredfibras_x_pisonatur_x_techootro
# new_paredfibras_x_pisonotiene_x_techozinc
# new_paredfibras_x_pisonotiene_x_techoentrepiso
# new_paredfibras_x_pisonotiene_x_techocane
# new_paredfibras_x_pisonotiene_x_techootro
# new_paredfibras_x_pisomadera_x_techozinc
# new_paredfibras_x_pisomadera_x_techoentrepiso
# new_paredfibras_x_pisomadera_x_techocane
# new_paredfibras_x_pisomadera_x_techootro
# new_paredother_x_pisomoscer_x_techozinc
# new_paredother_x_pisomoscer_x_techoentrepiso
# new_paredother_x_pisomoscer_x_techocane
# new_paredother_x_pisomoscer_x_techootro
# new_paredother_x_pisocemento_x_techoentrepiso
# new_paredother_x_pisocemento_x_techocane
# new_paredother_x_pisocemento_x_techootro
# new_paredother_x_pisoother_x_techozinc
# new_paredother_x_pisoother_x_techoentrepiso
# new_paredother_x_pisoother_x_techocane
# new_paredother_x_pisoother_x_techootro
# new_paredother_x_pisonatur_x_techozinc
# new_paredother_x_pisonatur_x_techoentrepiso
# new_paredother_x_pisonatur_x_techocane
# new_paredother_x_pisonatur_x_techootro
# new_paredother_x_pisonotiene_x_techozinc
# new_paredother_x_pisonotiene_x_techoentrepiso
# new_paredother_x_pisonotiene_x_techocane
# new_paredother_x_pisonotiene_x_techootro
# new_paredother_x_pisomadera_x_techozinc
# new_paredother_x_pisomadera_x_techoentrepiso
# new_paredother_x_pisomadera_x_techocane
# new_paredother_x_pisomadera_x_techootro

# %%
df_train.drop(cols_with_only_one_value, axis = 1, inplace = True)
df_test.drop(cols_with_only_one_value, axis = 1, inplace = True)

# %%
cols_train = np.array(sorted([col for col in df_train.columns if col != 'Target']))
cols_test = np.array(sorted(df_test.columns))

# %%
(cols_train == cols_test).sum() == len(cols_train)
# Out:
# True

# %%
def max_min(x):
    return x.max() - x.min()

# %%
agg_train = pd.DataFrame()
agg_test = pd.DataFrame()
for item in tqdm(family_size_features):
    for i, function in enumerate(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        if i == 6:
            new_col = item + '_new_' + 'max_min'
        else:
            new_col = item + '_new_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new_ aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 15/15 [00:11<00:00,  1.36it/s]
# new aggregate train set has 2988 rows, and 105 features
# new_ aggregate test set has 7352 rows, and 105 features

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']

for item in tqdm(aggr_list):
    for function in ['count', 'sum']:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        new_col = item + '_new_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
    
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 47/47 [00:01<00:00, 27.24it/s]
# new aggregate train set has 2988 rows, and 199 features
# new aggregate test set has 7352 rows, and 199 features

# %%
aggr_list = ['escolari', 'age', 'escolari_age', 'dependency', 'bedrooms', 'overcrowding', 'rooms', 'qmobilephone', 'v18q1']

for item in tqdm(aggr_list):
    for i, function in enumerate(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        
        if i == 6:
            new_col = item + '_new_' + 'max_min'
        else:
            new_col = item + '_new_' +function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 9/9 [00:06<00:00,  1.31it/s]
# new aggregate train set has 2988 rows, and 262 features
# new aggregate test set has 7352 rows, and 262 features

# %%
agg_test = agg_test.reset_index()
agg_train = agg_train.reset_index()

train_agg = pd.merge(df_train, agg_train, on = 'idhogar')
test = pd.merge(df_test, agg_test, on = 'idhogar')

train_agg.fillna(value = 0, inplace = True)
test.fillna(value = 0, inplace = True)

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 778) test shape: (23856, 777)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]
    
    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]
    
    train_agg = pd.merge(train_agg, group_train, on = [lugar, 'idhogar'])
    test = pd.merge(test, group_test, on = [lugar, 'idhogar'])

print('train shape:', train_agg.shape, 'test_shape:', test.shape)
# Out:
# train shape: (9557, 1060) test_shape: (23856, 1059)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
    
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 1342) test shape: (23856, 1341)

# %%
cols_nums = ['age', 'meaneduc', 'dependency', 
             'hogar_nin', 'hogar_adul', 'hogar_mayor', 'hogar_total',
             'bedrooms', 'overcrowding']

for function in tqdm(['mean','std','min','max','sum', 'count', max_min]):
    for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
        group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_train.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_train][2:]

        group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_test.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_test][2:]

        train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
        test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
        
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# 100%|██████████| 7/7 [03:05<00:00, 26.52s/it]
# train shape: (9557, 3316) test shape: (23856, 3315)

# %%
train = train_agg.query('parentesco1==1')

# %%
train['dependency'].replace(np.inf, 0, inplace = True)
test['dependency'].replace(np.inf, 0, inplace = True)

# %%
submission = test[['Id']]

train.drop(columns = ['idhogar','Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace = True)
test.drop(columns = ['idhogar','Id',  'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace = True)

correlation = train.corr()
correlation = correlation['Target'].sort_values(ascending = False)

# %%
print('final_ data size', train.shape, test.shape)
# Out:
# final_ data size (2973, 3304) (23856, 3303)

# %%
print(f'The most 20 positive feature: \n{correlation.head(40)}')
# Out:
# The most 20 positive feature:
# Target                                1.000000
# escolari_new_mean                     0.423626
# escolari_new_max                      0.373091
# new5_lugar4_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_max         0.334254
# new5_lugar5_idhogar_edjef_max         0.334254
# new5_lugar6_idhogar_edjef_max         0.334254
# new5_lugar2_idhogar_edjef_max         0.334254
# new5_lugar3_idhogar_edjef_max         0.334254
# new5_lugar6_idhogar_edjef_mean        0.333873
# new5_lugar1_idhogar_edjef_mean        0.333873
# new5_lugar5_idhogar_edjef_mean        0.333873
# new5_lugar4_idhogar_edjef_mean        0.333873
# new5_lugar2_idhogar_edjef_mean        0.333873
# new5_lugar3_idhogar_edjef_mean        0.333873
# new5_lugar2_idhogar_edjef_min         0.333791
# new5_lugar4_idhogar_edjef_min         0.333791
# new5_lugar6_idhogar_edjef_min         0.333791
# new5_lugar5_idhogar_edjef_min         0.333791
# new5_lugar3_idhogar_edjef_min         0.333791
# new5_lugar1_idhogar_edjef_min         0.333791
# edjef                                 0.333791
# escolari                              0.333791
# meaneduc                              0.331489
# new5_lugar5_idhogar_instlevel8_max    0.317815
# new5_lugar4_idhogar_instlevel8_max    0.317815
# new5_lugar6_idhogar_instlevel8_max    0.317815
# new5_lugar3_idhogar_instlevel8_max    0.317815
# new5_lugar1_idhogar_instlevel8_max    0.317815
# new5_lugar2_idhogar_instlevel8_max    0.317815
# escolari_new_min                      0.306693
# phones-per-capita                     0.299026
# new5_lugar1_idhogar_instlevel8_std    0.298251
# new5_lugar2_idhogar_instlevel8_std    0.298251
# new5_lugar3_idhogar_instlevel8_std    0.298251
# new5_lugar4_idhogar_instlevel8_std    0.298251
# new5_lugar5_idhogar_instlevel8_std    0.298251
# new5_lugar6_idhogar_instlevel8_std    0.298251
# new_epared3_xeviv3                    0.298196
# cielorazo                             0.295249
# Name: Target, dtype: float64

# %%
print(f'The most 20 negative feature: \n{correlation.tail(20)}')
# Out:
# The most 20 negative feature:
# new5_lugar5_idhogar_television_<function max_min at 0x7fa48943e7a0>    NaN
# new5_lugar5_idhogar_mobilephone_<function max_min at 0x7fa48943e7a0>   NaN
# new5_lugar5_idhogar_area1_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar5_idhogar_area2_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar5_idhogar_v18q_<function max_min at 0x7fa48943e7a0>          NaN
# new5_lugar6_idhogar_epared1_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_epared2_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_epared3_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_etecho1_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_etecho2_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_etecho3_<function max_min at 0x7fa48943e7a0>       NaN
# new5_lugar6_idhogar_eviv1_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar6_idhogar_eviv2_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar6_idhogar_eviv3_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar6_idhogar_refrig_<function max_min at 0x7fa48943e7a0>        NaN
# new5_lugar6_idhogar_television_<function max_min at 0x7fa48943e7a0>    NaN
# new5_lugar6_idhogar_mobilephone_<function max_min at 0x7fa48943e7a0>   NaN
# new5_lugar6_idhogar_area1_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar6_idhogar_area2_<function max_min at 0x7fa48943e7a0>         NaN
# new5_lugar6_idhogar_v18q_<function max_min at 0x7fa48943e7a0>          NaN
# Name: Target, dtype: float64

# %%
binary_cat_features = [col for col in train.columns if train[col].value_counts().shape[0] == 2]
object_features = ['edjefe', 'edjefa']

categorical_feats = binary_cat_features + object_features

# %%
def evaluate_macroF1_lgb(truth, predictions):
    pred_labels = predictions.reshape(len(np.unique(truth)),-1).argmax(axis=0)
    f1 = f1_score(truth, pred_labels, average='macro')
    return ('macroF1', f1, True)

# %%
y = train['Target']
train.drop(columns=['Target'], inplace=True)

# %%
def print_execution_time(start):
    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print('*'*20, "Execution ended in {:0>2}h {:0>2}m {:05.2f}s".format(int(hours),int(minutes),seconds), '*'*20)

# %%
def extract_good_features_using_shap_LGB(params, SEED):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'], 
                             learning_rate=params['learning_rate'],  
                             silent=True, 
                             metric='multi_logloss',
                             n_jobs=-1, n_estimators=10000, 
                             class_weight='balanced',
                             colsample_bytree = params['colsample_bytree'], 
                             min_split_gain= params['min_split_gain'], 
                             bagging_freq = params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves = params['num_leaves'], 
                             subsample = params['subsample'],
                             reg_alpha= params['reg_alpha'],
                             reg_lambda= params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                            )

    kfold = 5
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df  = pd.DataFrame()

    for i, (train_index, test_index) in enumerate(kf.split(train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = train.iloc[train_index], train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=categorical_feats,
                early_stopping_rounds=500, verbose=500)
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df  = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        print_execution_time(start)

    feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
    return feat_importance_df_shap

# %%
total_shap_df  = pd.DataFrame()
NUM_ITERATIONS = 50
for SEED in range(NUM_ITERATIONS):
    print('#'*40, '{} of {} iterations'.format(SEED+1, NUM_ITERATIONS), '#' * 40)
    params = {'max_depth': np.random.choice([5, 6, 7, 8, 10, 12, -1]),
             'learning_rate': np.random.rand() * 0.02,
              'colsample_bytree': np.random.rand() * (1 - 0.5) + 0.5,
              'subsample': np.random.rand() * (1 - 0.5) + 0.5,
              'min_split_gain': np.random.rand() * 0.2,
              'num_leaves': np.random.choice([32, 48, 64]),
              'reg_alpha': np.random.rand() * 2,
              'reg_lambda': np.random.rand() *2,
              'bagging_freq': np.random.randint(4) +1,
              'min_child_weight': np.random.randint(100) + 20
             }
    temp_shap_df = extract_good_features_using_shap_LGB(params, SEED)
    total_shap_df = pd.concat([total_shap_df, temp_shap_df])
# Out:
# ######################################## 1 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.946183	training's macroF1: 0.614156	valid_1's multi_logloss: 1.02927	valid_1's macroF1: 0.425088
# [1000]	training's multi_logloss: 0.798349	training's macroF1: 0.683662	valid_1's multi_logloss: 1.00137	valid_1's macroF1: 0.434367
# Early stopping, best iteration is:
# [876]	training's multi_logloss: 0.827418	training's macroF1: 0.665523	valid_1's multi_logloss: 1.00508	valid_1's macroF1: 0.440733
# ******************** Execution ended in 00h 01m 15.15s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.950813	training's macroF1: 0.619291	valid_1's multi_logloss: 1.00857	valid_1's macroF1: 0.453205
# [1000]	training's multi_logloss: 0.80311	training's macroF1: 0.685799	valid_1's multi_logloss: 0.978472	valid_1's macroF1: 0.453593
# [1500]	training's multi_logloss: 0.709017	training's macroF1: 0.738202	valid_1's multi_logloss: 0.970839	valid_1's macroF1: 0.449118
# Early stopping, best iteration is:
# [1295]	training's multi_logloss: 0.743305	training's macroF1: 0.722754	valid_1's multi_logloss: 0.973642	valid_1's macroF1: 0.467747
# ******************** Execution ended in 00h 01m 35.78s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.932541	training's macroF1: 0.616013	valid_1's multi_logloss: 1.04087	valid_1's macroF1: 0.395254
# Early stopping, best iteration is:
# [130]	training's multi_logloss: 1.17572	training's macroF1: 0.531377	valid_1's multi_logloss: 1.17164	valid_1's macroF1: 0.417269
# ******************** Execution ended in 00h 00m 33.19s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.94015	training's macroF1: 0.611497	valid_1's multi_logloss: 1.03557	valid_1's macroF1: 0.415127
# [1000]	training's multi_logloss: 0.79293	training's macroF1: 0.67983	valid_1's multi_logloss: 1.00003	valid_1's macroF1: 0.404321
# Early stopping, best iteration is:
# [704]	training's multi_logloss: 0.868892	training's macroF1: 0.649991	valid_1's multi_logloss: 1.01504	valid_1's macroF1: 0.42177
# ******************** Execution ended in 00h 01m 04.08s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.931093	training's macroF1: 0.605592	valid_1's multi_logloss: 1.08162	valid_1's macroF1: 0.394743
# [1000]	training's multi_logloss: 0.783416	training's macroF1: 0.682149	valid_1's multi_logloss: 1.05978	valid_1's macroF1: 0.409774
# [1500]	training's multi_logloss: 0.690936	training's macroF1: 0.726729	valid_1's multi_logloss: 1.05566	valid_1's macroF1: 0.412875
# Early stopping, best iteration is:
# [1198]	training's multi_logloss: 0.742347	training's macroF1: 0.699021	valid_1's multi_logloss: 1.05752	valid_1's macroF1: 0.413877
# ******************** Execution ended in 00h 01m 29.16s ********************
# ######################################## 2 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04755	training's macroF1: 0.523794	valid_1's multi_logloss: 1.06635	valid_1's macroF1: 0.429465
# [1000]	training's multi_logloss: 0.964813	training's macroF1: 0.570991	valid_1's multi_logloss: 1.05449	valid_1's macroF1: 0.444459
# Early stopping, best iteration is:
# [877]	training's multi_logloss: 0.981872	training's macroF1: 0.560478	valid_1's multi_logloss: 1.05658	valid_1's macroF1: 0.451449
# ******************** Execution ended in 00h 00m 34.06s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04198	training's macroF1: 0.516271	valid_1's multi_logloss: 1.05042	valid_1's macroF1: 0.412992
# [1000]	training's multi_logloss: 0.960832	training's macroF1: 0.565251	valid_1's multi_logloss: 1.04144	valid_1's macroF1: 0.413133
# Early stopping, best iteration is:
# [731]	training's multi_logloss: 0.999458	training's macroF1: 0.538806	valid_1's multi_logloss: 1.04683	valid_1's macroF1: 0.428621
# ******************** Execution ended in 00h 00m 30.85s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03997	training's macroF1: 0.527532	valid_1's multi_logloss: 1.06421	valid_1's macroF1: 0.392225
# Early stopping, best iteration is:
# [422]	training's multi_logloss: 1.05836	training's macroF1: 0.522506	valid_1's multi_logloss: 1.06551	valid_1's macroF1: 0.396066
# ******************** Execution ended in 00h 00m 22.63s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05167	training's macroF1: 0.518132	valid_1's multi_logloss: 1.03983	valid_1's macroF1: 0.39242
# Early stopping, best iteration is:
# [118]	training's multi_logloss: 1.19943	training's macroF1: 0.457766	valid_1's multi_logloss: 1.12509	valid_1's macroF1: 0.432991
# ******************** Execution ended in 00h 00m 16.37s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04723	training's macroF1: 0.518835	valid_1's multi_logloss: 1.06071	valid_1's macroF1: 0.397166
# [1000]	training's multi_logloss: 0.965829	training's macroF1: 0.559267	valid_1's multi_logloss: 1.05099	valid_1's macroF1: 0.415682
# [1500]	training's multi_logloss: 0.909063	training's macroF1: 0.593844	valid_1's multi_logloss: 1.04774	valid_1's macroF1: 0.419132
# Early stopping, best iteration is:
# [1179]	training's multi_logloss: 0.943419	training's macroF1: 0.573039	valid_1's multi_logloss: 1.04968	valid_1's macroF1: 0.429379
# ******************** Execution ended in 00h 00m 43.67s ********************
# ######################################## 3 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.739418	training's macroF1: 0.717268	valid_1's multi_logloss: 0.976478	valid_1's macroF1: 0.437698
# [1000]	training's multi_logloss: 0.565795	training's macroF1: 0.794077	valid_1's multi_logloss: 0.956206	valid_1's macroF1: 0.443621
# [1500]	training's multi_logloss: 0.471058	training's macroF1: 0.829431	valid_1's multi_logloss: 0.949671	valid_1's macroF1: 0.443004
# Early stopping, best iteration is:
# [1004]	training's multi_logloss: 0.564813	training's macroF1: 0.796195	valid_1's multi_logloss: 0.956078	valid_1's macroF1: 0.450692
# ******************** Execution ended in 00h 01m 11.14s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.725996	training's macroF1: 0.728921	valid_1's multi_logloss: 1.01362	valid_1's macroF1: 0.391536
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 1.34028	training's macroF1: 0.511075	valid_1's multi_logloss: 1.33325	valid_1's macroF1: 0.41024
# ******************** Execution ended in 00h 00m 21.06s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.739949	training's macroF1: 0.714548	valid_1's multi_logloss: 0.99335	valid_1's macroF1: 0.428577
# Early stopping, best iteration is:
# [347]	training's multi_logloss: 0.827216	training's macroF1: 0.67906	valid_1's multi_logloss: 1.00807	valid_1's macroF1: 0.438559
# ******************** Execution ended in 00h 00m 41.25s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.734701	training's macroF1: 0.710972	valid_1's multi_logloss: 0.984077	valid_1's macroF1: 0.433291
# Early stopping, best iteration is:
# [310]	training's multi_logloss: 0.84856	training's macroF1: 0.670721	valid_1's multi_logloss: 0.996985	valid_1's macroF1: 0.448192
# ******************** Execution ended in 00h 00m 37.18s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.727766	training's macroF1: 0.723497	valid_1's multi_logloss: 1.02029	valid_1's macroF1: 0.420698
# [1000]	training's multi_logloss: 0.556666	training's macroF1: 0.787685	valid_1's multi_logloss: 1.00564	valid_1's macroF1: 0.415418
# Early stopping, best iteration is:
# [567]	training's multi_logloss: 0.695995	training's macroF1: 0.740465	valid_1's multi_logloss: 1.01583	valid_1's macroF1: 0.432714
# ******************** Execution ended in 00h 00m 51.37s ********************
# ######################################## 4 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.968464	training's macroF1: 0.576018	valid_1's multi_logloss: 1.02284	valid_1's macroF1: 0.400686
# [1000]	training's multi_logloss: 0.849093	training's macroF1: 0.647956	valid_1's multi_logloss: 1.00397	valid_1's macroF1: 0.425293
# [1500]	training's multi_logloss: 0.770708	training's macroF1: 0.683275	valid_1's multi_logloss: 1.00046	valid_1's macroF1: 0.430062
# [2000]	training's multi_logloss: 0.712085	training's macroF1: 0.710216	valid_1's multi_logloss: 0.999755	valid_1's macroF1: 0.429382
# Early stopping, best iteration is:
# [1710]	training's multi_logloss: 0.744368	training's macroF1: 0.694603	valid_1's multi_logloss: 0.999144	valid_1's macroF1: 0.424517
# ******************** Execution ended in 00h 01m 28.30s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.953711	training's macroF1: 0.579884	valid_1's multi_logloss: 1.07111	valid_1's macroF1: 0.421281
# Early stopping, best iteration is:
# [390]	training's multi_logloss: 0.992649	training's macroF1: 0.556635	valid_1's multi_logloss: 1.07609	valid_1's macroF1: 0.424349
# ******************** Execution ended in 00h 00m 35.81s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.961237	training's macroF1: 0.588329	valid_1's multi_logloss: 1.0378	valid_1's macroF1: 0.42233
# [1000]	training's multi_logloss: 0.840372	training's macroF1: 0.64867	valid_1's multi_logloss: 1.01864	valid_1's macroF1: 0.419818
# Early stopping, best iteration is:
# [528]	training's multi_logloss: 0.952524	training's macroF1: 0.592177	valid_1's multi_logloss: 1.03568	valid_1's macroF1: 0.427682
# ******************** Execution ended in 00h 00m 41.87s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.965307	training's macroF1: 0.578898	valid_1's multi_logloss: 1.03346	valid_1's macroF1: 0.410088
# [1000]	training's multi_logloss: 0.847819	training's macroF1: 0.641401	valid_1's multi_logloss: 1.01857	valid_1's macroF1: 0.418538
# Early stopping, best iteration is:
# [792]	training's multi_logloss: 0.888909	training's macroF1: 0.61657	valid_1's multi_logloss: 1.02364	valid_1's macroF1: 0.421171
# ******************** Execution ended in 00h 00m 53.07s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.958282	training's macroF1: 0.590187	valid_1's multi_logloss: 1.04102	valid_1's macroF1: 0.392362
# [1000]	training's multi_logloss: 0.839429	training's macroF1: 0.649223	valid_1's multi_logloss: 1.02933	valid_1's macroF1: 0.410053
# [1500]	training's multi_logloss: 0.761615	training's macroF1: 0.689277	valid_1's multi_logloss: 1.02639	valid_1's macroF1: 0.404866
# Early stopping, best iteration is:
# [1025]	training's multi_logloss: 0.834728	training's macroF1: 0.650929	valid_1's multi_logloss: 1.02945	valid_1's macroF1: 0.416721
# ******************** Execution ended in 00h 01m 01.74s ********************
# ######################################## 5 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07595	training's macroF1: 0.497136	valid_1's multi_logloss: 1.08551	valid_1's macroF1: 0.374439
# Early stopping, best iteration is:
# [78]	training's multi_logloss: 1.23385	training's macroF1: 0.433974	valid_1's multi_logloss: 1.18143	valid_1's macroF1: 0.398768
# ******************** Execution ended in 00h 00m 15.02s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0878	training's macroF1: 0.489122	valid_1's multi_logloss: 1.05019	valid_1's macroF1: 0.424166
# [1000]	training's multi_logloss: 1.02376	training's macroF1: 0.522308	valid_1's multi_logloss: 1.03638	valid_1's macroF1: 0.44592
# Early stopping, best iteration is:
# [987]	training's multi_logloss: 1.02524	training's macroF1: 0.519767	valid_1's multi_logloss: 1.03745	valid_1's macroF1: 0.450267
# ******************** Execution ended in 00h 00m 40.40s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07989	training's macroF1: 0.503891	valid_1's multi_logloss: 1.10307	valid_1's macroF1: 0.397761
# [1000]	training's multi_logloss: 1.0154	training's macroF1: 0.527732	valid_1's multi_logloss: 1.09657	valid_1's macroF1: 0.402139
# [1500]	training's multi_logloss: 0.971855	training's macroF1: 0.5428	valid_1's multi_logloss: 1.09318	valid_1's macroF1: 0.407814
# [2000]	training's multi_logloss: 0.939678	training's macroF1: 0.560856	valid_1's multi_logloss: 1.09392	valid_1's macroF1: 0.424877
# Early stopping, best iteration is:
# [1744]	training's multi_logloss: 0.95545	training's macroF1: 0.553931	valid_1's multi_logloss: 1.09109	valid_1's macroF1: 0.423227
# ******************** Execution ended in 00h 00m 57.48s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07481	training's macroF1: 0.510505	valid_1's multi_logloss: 1.08246	valid_1's macroF1: 0.376447
# [1000]	training's multi_logloss: 1.00855	training's macroF1: 0.542414	valid_1's multi_logloss: 1.07212	valid_1's macroF1: 0.385751
# Early stopping, best iteration is:
# [614]	training's multi_logloss: 1.057	training's macroF1: 0.522009	valid_1's multi_logloss: 1.07769	valid_1's macroF1: 0.398228
# ******************** Execution ended in 00h 00m 47.02s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07987	training's macroF1: 0.493468	valid_1's multi_logloss: 1.0693	valid_1's macroF1: 0.394963
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 1.33988	training's macroF1: 0.417658	valid_1's multi_logloss: 1.313	valid_1's macroF1: 0.404186
# ******************** Execution ended in 00h 00m 13.71s ********************
# ######################################## 6 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24641	training's macroF1: 0.423767	valid_1's multi_logloss: 1.16473	valid_1's macroF1: 0.403135
# [1000]	training's multi_logloss: 1.20088	training's macroF1: 0.443336	valid_1's multi_logloss: 1.11233	valid_1's macroF1: 0.40744
# [1500]	training's multi_logloss: 1.17593	training's macroF1: 0.449142	valid_1's multi_logloss: 1.08825	valid_1's macroF1: 0.407846
# Early stopping, best iteration is:
# [1110]	training's multi_logloss: 1.194	training's macroF1: 0.442454	valid_1's multi_logloss: 1.10452	valid_1's macroF1: 0.424641
# ******************** Execution ended in 00h 00m 32.11s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24557	training's macroF1: 0.4228	valid_1's multi_logloss: 1.17257	valid_1's macroF1: 0.399558
# Early stopping, best iteration is:
# [260]	training's multi_logloss: 1.2887	training's macroF1: 0.414432	valid_1's multi_logloss: 1.23149	valid_1's macroF1: 0.416594
# ******************** Execution ended in 00h 00m 16.69s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24517	training's macroF1: 0.412161	valid_1's multi_logloss: 1.15566	valid_1's macroF1: 0.383306
# [1000]	training's multi_logloss: 1.19943	training's macroF1: 0.429241	valid_1's multi_logloss: 1.10307	valid_1's macroF1: 0.395814
# [1500]	training's multi_logloss: 1.17414	training's macroF1: 0.4429	valid_1's multi_logloss: 1.08395	valid_1's macroF1: 0.413282
# [2000]	training's multi_logloss: 1.15653	training's macroF1: 0.450692	valid_1's multi_logloss: 1.07664	valid_1's macroF1: 0.413638
# Early stopping, best iteration is:
# [1826]	training's multi_logloss: 1.16201	training's macroF1: 0.446979	valid_1's multi_logloss: 1.08088	valid_1's macroF1: 0.423167
# ******************** Execution ended in 00h 00m 44.29s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23802	training's macroF1: 0.42461	valid_1's multi_logloss: 1.17154	valid_1's macroF1: 0.381387
# [1000]	training's multi_logloss: 1.18993	training's macroF1: 0.449837	valid_1's multi_logloss: 1.12702	valid_1's macroF1: 0.380501
# [1500]	training's multi_logloss: 1.16442	training's macroF1: 0.460516	valid_1's multi_logloss: 1.10801	valid_1's macroF1: 0.384347
# Early stopping, best iteration is:
# [1109]	training's multi_logloss: 1.18302	training's macroF1: 0.452822	valid_1's multi_logloss: 1.12127	valid_1's macroF1: 0.397888
# ******************** Execution ended in 00h 00m 33.19s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24116	training's macroF1: 0.424339	valid_1's multi_logloss: 1.183	valid_1's macroF1: 0.392705
# Early stopping, best iteration is:
# [344]	training's multi_logloss: 1.26695	training's macroF1: 0.416823	valid_1's multi_logloss: 1.21193	valid_1's macroF1: 0.40515
# ******************** Execution ended in 00h 00m 16.92s ********************
# ######################################## 7 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.924842	training's macroF1: 0.591416	valid_1's multi_logloss: 1.0302	valid_1's macroF1: 0.436446
# Early stopping, best iteration is:
# [123]	training's multi_logloss: 1.10951	training's macroF1: 0.499405	valid_1's multi_logloss: 1.07191	valid_1's macroF1: 0.459345
# ******************** Execution ended in 00h 00m 15.53s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.921453	training's macroF1: 0.583542	valid_1's multi_logloss: 1.01215	valid_1's macroF1: 0.415404
# [1000]	training's multi_logloss: 0.803868	training's macroF1: 0.652227	valid_1's multi_logloss: 1.00704	valid_1's macroF1: 0.422354
# Early stopping, best iteration is:
# [942]	training's multi_logloss: 0.814384	training's macroF1: 0.650304	valid_1's multi_logloss: 1.00374	valid_1's macroF1: 0.429014
# ******************** Execution ended in 00h 00m 36.37s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.922059	training's macroF1: 0.593699	valid_1's multi_logloss: 1.0613	valid_1's macroF1: 0.424439
# Early stopping, best iteration is:
# [378]	training's multi_logloss: 0.960609	training's macroF1: 0.574405	valid_1's multi_logloss: 1.05785	valid_1's macroF1: 0.417885
# ******************** Execution ended in 00h 00m 21.69s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.922821	training's macroF1: 0.605689	valid_1's multi_logloss: 1.01598	valid_1's macroF1: 0.397268
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.29839	training's macroF1: 0.438362	valid_1's multi_logloss: 1.25496	valid_1's macroF1: 0.438632
# ******************** Execution ended in 00h 00m 13.47s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.913027	training's macroF1: 0.587795	valid_1's multi_logloss: 1.05907	valid_1's macroF1: 0.399491
# Early stopping, best iteration is:
# [378]	training's multi_logloss: 0.95441	training's macroF1: 0.570712	valid_1's multi_logloss: 1.05822	valid_1's macroF1: 0.419998
# ******************** Execution ended in 00h 00m 23.32s ********************
# ######################################## 8 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.92682	training's macroF1: 0.592223	valid_1's multi_logloss: 1.02701	valid_1's macroF1: 0.389641
# [1000]	training's multi_logloss: 0.809436	training's macroF1: 0.662704	valid_1's multi_logloss: 1.01364	valid_1's macroF1: 0.393586
# Early stopping, best iteration is:
# [552]	training's multi_logloss: 0.911611	training's macroF1: 0.602342	valid_1's multi_logloss: 1.02246	valid_1's macroF1: 0.404348
# ******************** Execution ended in 00h 00m 29.45s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.930936	training's macroF1: 0.589572	valid_1's multi_logloss: 1.0308	valid_1's macroF1: 0.415033
# Early stopping, best iteration is:
# [187]	training's multi_logloss: 1.07199	training's macroF1: 0.530986	valid_1's multi_logloss: 1.05925	valid_1's macroF1: 0.429564
# ******************** Execution ended in 00h 00m 17.89s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.931353	training's macroF1: 0.587653	valid_1's multi_logloss: 1.04922	valid_1's macroF1: 0.410117
# [1000]	training's multi_logloss: 0.806279	training's macroF1: 0.65574	valid_1's multi_logloss: 1.04095	valid_1's macroF1: 0.414437
# Early stopping, best iteration is:
# [645]	training's multi_logloss: 0.889193	training's macroF1: 0.606759	valid_1's multi_logloss: 1.04895	valid_1's macroF1: 0.430684
# ******************** Execution ended in 00h 00m 30.48s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.917583	training's macroF1: 0.59396	valid_1's multi_logloss: 1.05752	valid_1's macroF1: 0.401654
# Early stopping, best iteration is:
# [192]	training's multi_logloss: 1.05666	training's macroF1: 0.535962	valid_1's multi_logloss: 1.07345	valid_1's macroF1: 0.40902
# ******************** Execution ended in 00h 00m 19.70s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.941379	training's macroF1: 0.596917	valid_1's multi_logloss: 0.990315	valid_1's macroF1: 0.43901
# [1000]	training's multi_logloss: 0.819475	training's macroF1: 0.663913	valid_1's multi_logloss: 0.984804	valid_1's macroF1: 0.432499
# Early stopping, best iteration is:
# [504]	training's multi_logloss: 0.939806	training's macroF1: 0.59962	valid_1's multi_logloss: 0.990541	valid_1's macroF1: 0.444778
# ******************** Execution ended in 00h 00m 26.90s ********************
# ######################################## 9 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00677	training's macroF1: 0.546127	valid_1's multi_logloss: 1.05851	valid_1's macroF1: 0.359015
# Early stopping, best iteration is:
# [81]	training's multi_logloss: 1.21548	training's macroF1: 0.464521	valid_1's multi_logloss: 1.15659	valid_1's macroF1: 0.397543
# ******************** Execution ended in 00h 00m 21.61s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02651	training's macroF1: 0.530548	valid_1's multi_logloss: 1.03617	valid_1's macroF1: 0.404404
# [1000]	training's multi_logloss: 0.936487	training's macroF1: 0.58154	valid_1's multi_logloss: 1.01381	valid_1's macroF1: 0.41625
# Early stopping, best iteration is:
# [797]	training's multi_logloss: 0.967672	training's macroF1: 0.561196	valid_1's multi_logloss: 1.02051	valid_1's macroF1: 0.43075
# ******************** Execution ended in 00h 00m 47.38s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02004	training's macroF1: 0.538171	valid_1's multi_logloss: 1.07512	valid_1's macroF1: 0.400718
# Early stopping, best iteration is:
# [224]	training's multi_logloss: 1.10892	training's macroF1: 0.495462	valid_1's multi_logloss: 1.0999	valid_1's macroF1: 0.429072
# ******************** Execution ended in 00h 00m 27.85s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00924	training's macroF1: 0.544822	valid_1's multi_logloss: 1.06956	valid_1's macroF1: 0.398576
# [1000]	training's multi_logloss: 0.916729	training's macroF1: 0.585708	valid_1's multi_logloss: 1.06478	valid_1's macroF1: 0.412139
# [1500]	training's multi_logloss: 0.856566	training's macroF1: 0.628015	valid_1's multi_logloss: 1.06416	valid_1's macroF1: 0.421963
# [2000]	training's multi_logloss: 0.811855	training's macroF1: 0.650826	valid_1's multi_logloss: 1.06462	valid_1's macroF1: 0.422989
# Early stopping, best iteration is:
# [1667]	training's multi_logloss: 0.840331	training's macroF1: 0.631698	valid_1's multi_logloss: 1.06318	valid_1's macroF1: 0.422973
# ******************** Execution ended in 00h 01m 17.61s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.01087	training's macroF1: 0.531827	valid_1's multi_logloss: 1.0708	valid_1's macroF1: 0.408266
# Early stopping, best iteration is:
# [81]	training's multi_logloss: 1.21778	training's macroF1: 0.455573	valid_1's multi_logloss: 1.17371	valid_1's macroF1: 0.434278
# ******************** Execution ended in 00h 00m 22.96s ********************
# ######################################## 10 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.946375	training's macroF1: 0.587471	valid_1's multi_logloss: 1.04111	valid_1's macroF1: 0.405619
# Early stopping, best iteration is:
# [354]	training's multi_logloss: 1.00353	training's macroF1: 0.564557	valid_1's multi_logloss: 1.05231	valid_1's macroF1: 0.420163
# ******************** Execution ended in 00h 00m 33.07s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.954671	training's macroF1: 0.576273	valid_1's multi_logloss: 1.03129	valid_1's macroF1: 0.452817
# Early stopping, best iteration is:
# [445]	training's multi_logloss: 0.972986	training's macroF1: 0.57077	valid_1's multi_logloss: 1.03379	valid_1's macroF1: 0.466637
# ******************** Execution ended in 00h 00m 38.09s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.925961	training's macroF1: 0.593132	valid_1's multi_logloss: 1.04278	valid_1's macroF1: 0.403359
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.33395	training's macroF1: 0.462732	valid_1's multi_logloss: 1.31899	valid_1's macroF1: 0.419193
# ******************** Execution ended in 00h 00m 19.60s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.934526	training's macroF1: 0.599307	valid_1's multi_logloss: 1.05307	valid_1's macroF1: 0.398167
# [1000]	training's multi_logloss: 0.810882	training's macroF1: 0.657214	valid_1's multi_logloss: 1.04224	valid_1's macroF1: 0.412285
# [1500]	training's multi_logloss: 0.729957	training's macroF1: 0.705619	valid_1's multi_logloss: 1.03966	valid_1's macroF1: 0.410249
# Early stopping, best iteration is:
# [1441]	training's multi_logloss: 0.738078	training's macroF1: 0.701777	valid_1's multi_logloss: 1.03927	valid_1's macroF1: 0.418318
# ******************** Execution ended in 00h 01m 16.15s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.930482	training's macroF1: 0.599142	valid_1's multi_logloss: 1.02196	valid_1's macroF1: 0.411719
# Early stopping, best iteration is:
# [471]	training's multi_logloss: 0.940377	training's macroF1: 0.594263	valid_1's multi_logloss: 1.02357	valid_1's macroF1: 0.412263
# ******************** Execution ended in 00h 00m 39.07s ********************
# ######################################## 11 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24204	training's macroF1: 0.453431	valid_1's multi_logloss: 1.18275	valid_1's macroF1: 0.411197
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 1.38296	training's macroF1: 0.432237	valid_1's multi_logloss: 1.38121	valid_1's macroF1: 0.426075
# ******************** Execution ended in 00h 00m 16.75s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23515	training's macroF1: 0.465452	valid_1's multi_logloss: 1.20032	valid_1's macroF1: 0.390666
# Early stopping, best iteration is:
# [174]	training's multi_logloss: 1.31858	training's macroF1: 0.454683	valid_1's multi_logloss: 1.29699	valid_1's macroF1: 0.39434
# ******************** Execution ended in 00h 00m 22.88s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23468	training's macroF1: 0.467533	valid_1's multi_logloss: 1.19862	valid_1's macroF1: 0.399655
# [1000]	training's multi_logloss: 1.15586	training's macroF1: 0.49263	valid_1's multi_logloss: 1.12871	valid_1's macroF1: 0.399549
# Early stopping, best iteration is:
# [720]	training's multi_logloss: 1.19446	training's macroF1: 0.48053	valid_1's multi_logloss: 1.16005	valid_1's macroF1: 0.414598
# ******************** Execution ended in 00h 00m 42.70s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24138	training's macroF1: 0.461971	valid_1's multi_logloss: 1.19128	valid_1's macroF1: 0.401909
# [1000]	training's multi_logloss: 1.16738	training's macroF1: 0.490678	valid_1's multi_logloss: 1.11599	valid_1's macroF1: 0.421102
# [1500]	training's multi_logloss: 1.11984	training's macroF1: 0.499369	valid_1's multi_logloss: 1.07937	valid_1's macroF1: 0.434906
# [2000]	training's multi_logloss: 1.08449	training's macroF1: 0.526818	valid_1's multi_logloss: 1.05793	valid_1's macroF1: 0.445274
# [2500]	training's multi_logloss: 1.05619	training's macroF1: 0.538615	valid_1's multi_logloss: 1.04474	valid_1's macroF1: 0.444206
# Early stopping, best iteration is:
# [2108]	training's multi_logloss: 1.07792	training's macroF1: 0.528899	valid_1's multi_logloss: 1.05479	valid_1's macroF1: 0.456695
# ******************** Execution ended in 00h 01m 31.21s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22749	training's macroF1: 0.477059	valid_1's multi_logloss: 1.19427	valid_1's macroF1: 0.357649
# Early stopping, best iteration is:
# [450]	training's multi_logloss: 1.23847	training's macroF1: 0.476853	valid_1's multi_logloss: 1.2052	valid_1's macroF1: 0.372927
# ******************** Execution ended in 00h 00m 32.79s ********************
# ######################################## 12 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.924546	training's macroF1: 0.587089	valid_1's multi_logloss: 1.02577	valid_1's macroF1: 0.402121
# Early stopping, best iteration is:
# [90]	training's multi_logloss: 1.15377	training's macroF1: 0.498369	valid_1's multi_logloss: 1.10117	valid_1's macroF1: 0.434623
# ******************** Execution ended in 00h 00m 18.27s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.918323	training's macroF1: 0.600357	valid_1's multi_logloss: 1.03926	valid_1's macroF1: 0.425892
# [1000]	training's multi_logloss: 0.80151	training's macroF1: 0.659464	valid_1's multi_logloss: 1.03603	valid_1's macroF1: 0.41721
# Early stopping, best iteration is:
# [681]	training's multi_logloss: 0.870799	training's macroF1: 0.626566	valid_1's multi_logloss: 1.03732	valid_1's macroF1: 0.431825
# ******************** Execution ended in 00h 00m 33.18s ********************
# ...
# [1234]	training's multi_logloss: 1.03262	training's macroF1: 0.523915	valid_1's multi_logloss: 1.07691	valid_1's macroF1: 0.423295
# ******************** Execution ended in 00h 00m 51.28s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11604	training's macroF1: 0.480712	valid_1's multi_logloss: 1.06258	valid_1's macroF1: 0.435578
# Early stopping, best iteration is:
# [211]	training's multi_logloss: 1.1892	training's macroF1: 0.450077	valid_1's multi_logloss: 1.11307	valid_1's macroF1: 0.448499
# ******************** Execution ended in 00h 00m 20.29s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.10516	training's macroF1: 0.484796	valid_1's multi_logloss: 1.08242	valid_1's macroF1: 0.3823
# [1000]	training's multi_logloss: 1.03916	training's macroF1: 0.516124	valid_1's multi_logloss: 1.07613	valid_1's macroF1: 0.36933
# Early stopping, best iteration is:
# [529]	training's multi_logloss: 1.09992	training's macroF1: 0.489762	valid_1's multi_logloss: 1.07941	valid_1's macroF1: 0.388978
# ******************** Execution ended in 00h 00m 42.90s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1106	training's macroF1: 0.492516	valid_1's multi_logloss: 1.09363	valid_1's macroF1: 0.387397
# [1000]	training's multi_logloss: 1.04991	training's macroF1: 0.522048	valid_1's multi_logloss: 1.08857	valid_1's macroF1: 0.405727
# [1500]	training's multi_logloss: 1.0084	training's macroF1: 0.537453	valid_1's multi_logloss: 1.08619	valid_1's macroF1: 0.404693
# Early stopping, best iteration is:
# [1281]	training's multi_logloss: 1.02539	training's macroF1: 0.531582	valid_1's multi_logloss: 1.08648	valid_1's macroF1: 0.414494
# ******************** Execution ended in 00h 00m 51.40s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11115	training's macroF1: 0.478604	valid_1's multi_logloss: 1.07904	valid_1's macroF1: 0.381715
# [1000]	training's multi_logloss: 1.04968	training's macroF1: 0.523767	valid_1's multi_logloss: 1.06808	valid_1's macroF1: 0.396298
# [1500]	training's multi_logloss: 1.00818	training's macroF1: 0.542313	valid_1's multi_logloss: 1.06391	valid_1's macroF1: 0.387241
# Early stopping, best iteration is:
# [1204]	training's multi_logloss: 1.03173	training's macroF1: 0.529072	valid_1's multi_logloss: 1.06568	valid_1's macroF1: 0.402941
# ******************** Execution ended in 00h 00m 50.72s ********************
# ######################################## 48 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07966	training's macroF1: 0.516059	valid_1's multi_logloss: 1.07026	valid_1's macroF1: 0.420442
# Early stopping, best iteration is:
# [499]	training's multi_logloss: 1.07988	training's macroF1: 0.515398	valid_1's multi_logloss: 1.07037	valid_1's macroF1: 0.425881
# ******************** Execution ended in 00h 00m 31.01s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07004	training's macroF1: 0.511212	valid_1's multi_logloss: 1.09331	valid_1's macroF1: 0.373862
# [1000]	training's multi_logloss: 0.983437	training's macroF1: 0.544798	valid_1's multi_logloss: 1.08222	valid_1's macroF1: 0.386543
# [1500]	training's multi_logloss: 0.927166	training's macroF1: 0.575873	valid_1's multi_logloss: 1.07601	valid_1's macroF1: 0.399108
# [2000]	training's multi_logloss: 0.883056	training's macroF1: 0.604375	valid_1's multi_logloss: 1.07506	valid_1's macroF1: 0.399811
# [2500]	training's multi_logloss: 0.847198	training's macroF1: 0.624271	valid_1's multi_logloss: 1.07335	valid_1's macroF1: 0.404537
# Early stopping, best iteration is:
# [2440]	training's multi_logloss: 0.851254	training's macroF1: 0.62047	valid_1's multi_logloss: 1.07285	valid_1's macroF1: 0.406365
# ******************** Execution ended in 00h 01m 31.66s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07763	training's macroF1: 0.510939	valid_1's multi_logloss: 1.03638	valid_1's macroF1: 0.405004
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.37659	training's macroF1: 0.432262	valid_1's multi_logloss: 1.36983	valid_1's macroF1: 0.421382
# ******************** Execution ended in 00h 00m 15.17s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.075	training's macroF1: 0.507859	valid_1's multi_logloss: 1.04793	valid_1's macroF1: 0.429443
# Early stopping, best iteration is:
# [427]	training's multi_logloss: 1.09308	training's macroF1: 0.501711	valid_1's multi_logloss: 1.05553	valid_1's macroF1: 0.432887
# ******************** Execution ended in 00h 00m 29.34s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06051	training's macroF1: 0.523343	valid_1's multi_logloss: 1.10106	valid_1's macroF1: 0.366065
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.36541	training's macroF1: 0.426696	valid_1's multi_logloss: 1.3575	valid_1's macroF1: 0.373526
# ******************** Execution ended in 00h 00m 17.00s ********************
# ######################################## 49 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16701	training's macroF1: 0.549806	valid_1's multi_logloss: 1.14199	valid_1's macroF1: 0.399284
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.38151	training's macroF1: 0.469934	valid_1's multi_logloss: 1.38053	valid_1's macroF1: 0.405739
# ******************** Execution ended in 00h 00m 17.38s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1643	training's macroF1: 0.526245	valid_1's multi_logloss: 1.16389	valid_1's macroF1: 0.380684
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 1.37471	training's macroF1: 0.483799	valid_1's multi_logloss: 1.37302	valid_1's macroF1: 0.408325
# ******************** Execution ended in 00h 00m 18.17s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17184	training's macroF1: 0.544315	valid_1's multi_logloss: 1.14907	valid_1's macroF1: 0.413069
# Early stopping, best iteration is:
# [39]	training's multi_logloss: 1.3617	training's macroF1: 0.507765	valid_1's multi_logloss: 1.35544	valid_1's macroF1: 0.440525
# ******************** Execution ended in 00h 00m 20.05s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16695	training's macroF1: 0.548772	valid_1's multi_logloss: 1.14262	valid_1's macroF1: 0.419722
# [1000]	training's multi_logloss: 1.05459	training's macroF1: 0.588153	valid_1's multi_logloss: 1.05478	valid_1's macroF1: 0.44221
# [1500]	training's multi_logloss: 0.979833	training's macroF1: 0.613312	valid_1's multi_logloss: 1.01589	valid_1's macroF1: 0.449558
# [2000]	training's multi_logloss: 0.922056	training's macroF1: 0.641067	valid_1's multi_logloss: 0.996099	valid_1's macroF1: 0.457055
# [2500]	training's multi_logloss: 0.875415	training's macroF1: 0.666462	valid_1's multi_logloss: 0.982905	valid_1's macroF1: 0.460517
# Early stopping, best iteration is:
# [2168]	training's multi_logloss: 0.905696	training's macroF1: 0.650774	valid_1's multi_logloss: 0.99079	valid_1's macroF1: 0.468327
# ******************** Execution ended in 00h 01m 53.53s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16101	training's macroF1: 0.552088	valid_1's multi_logloss: 1.14584	valid_1's macroF1: 0.368138
# Early stopping, best iteration is:
# [76]	training's multi_logloss: 1.33744	training's macroF1: 0.511185	valid_1's multi_logloss: 1.3271	valid_1's macroF1: 0.394609
# ******************** Execution ended in 00h 00m 21.59s ********************
# ######################################## 50 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.665348	training's macroF1: 0.757436	valid_1's multi_logloss: 0.994925	valid_1's macroF1: 0.402575
# Early stopping, best iteration is:
# [164]	training's multi_logloss: 0.948671	training's macroF1: 0.644503	valid_1's multi_logloss: 1.05341	valid_1's macroF1: 0.421501
# ******************** Execution ended in 00h 00m 34.92s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.659387	training's macroF1: 0.765773	valid_1's multi_logloss: 0.970364	valid_1's macroF1: 0.43823
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 1.03453	training's macroF1: 0.617671	valid_1's multi_logloss: 1.08212	valid_1's macroF1: 0.45541
# ******************** Execution ended in 00h 00m 29.13s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.667881	training's macroF1: 0.758457	valid_1's multi_logloss: 0.957786	valid_1's macroF1: 0.409594
# [1000]	training's multi_logloss: 0.487039	training's macroF1: 0.826829	valid_1's multi_logloss: 0.938804	valid_1's macroF1: 0.421247
# [1500]	training's multi_logloss: 0.393117	training's macroF1: 0.858841	valid_1's multi_logloss: 0.933518	valid_1's macroF1: 0.434292
# Early stopping, best iteration is:
# [1107]	training's multi_logloss: 0.462027	training's macroF1: 0.837619	valid_1's multi_logloss: 0.937247	valid_1's macroF1: 0.438157
# ******************** Execution ended in 00h 01m 24.58s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.669744	training's macroF1: 0.761401	valid_1's multi_logloss: 0.945469	valid_1's macroF1: 0.436779
# Early stopping, best iteration is:
# [238]	training's multi_logloss: 0.865268	training's macroF1: 0.676006	valid_1's multi_logloss: 0.979403	valid_1's macroF1: 0.455025
# ******************** Execution ended in 00h 00m 39.28s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.667632	training's macroF1: 0.762114	valid_1's multi_logloss: 1.02721	valid_1's macroF1: 0.413751
# Early stopping, best iteration is:
# [359]	training's multi_logloss: 0.756726	training's macroF1: 0.71914	valid_1's multi_logloss: 1.03598	valid_1's macroF1: 0.427211
# ******************** Execution ended in 00h 00m 45.53s ********************

# %%
shap_sorted_df = total_shap_df.groupby('feature').mean().sort_values('shap_values', ascending = False).reset_index()
feat_imp_sorted_df = total_shap_df.groupby('feature').mean().sort_values('feat_imp', ascending = False).reset_index()
features_top_shap = shap_sorted_df['feature'][:500]
features_top_feat_imp = feat_imp_sorted_df['feature'][:500]
top_features = pd.Series(features_top_shap.tolist() + features_top_feat_imp.tolist())
top_features = top_features.unique()

# %%
new_train = train[top_features].copy()
new_test = test[top_features].copy()

# %%
print('new_train shape:', new_train.shape, 'new_test shape:', new_test.shape)
# Out:
# new_train shape: (2973, 525) new_test shape: (23856, 525)

# %%
new_categorical_feats = [col for col in top_features if col in categorical_feats]

# %%
def LGB_OOF(params, categorical_feats, N_FOLDs, SEED=1989):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'], 
                             learning_rate=params['learning_rate'],  
                             silent=True, 
                             metric='multi_logloss',
                             n_jobs=-1, n_estimators=10000, 
                             class_weight='balanced',
                             colsample_bytree = params['colsample_bytree'], 
                             min_split_gain= params['min_split_gain'], 
                             bagging_freq = params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves = params['num_leaves'], 
                             subsample = params['subsample'],
                             reg_alpha= params['reg_alpha'],
                             reg_lambda= params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                            )

    kfold = 10
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df  = pd.DataFrame()
    predicts_result = []

    for i, (train_index, test_index) in enumerate(kf.split(new_train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = new_train.iloc[train_index], new_train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb,categorical_feature=new_categorical_feats,
                early_stopping_rounds=500, verbose=500)
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df  = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        predicts_result.append(clf.predict(new_test))
        print_execution_time(start)
    return predicts_result, feat_importance_df

# %%
params = {'max_depth':6, 'learning_rate':0.002, 'colsample_bytree':0.8,
         'subsample':0.8, 'min_split_gain':0.02, 'num_leaves':48, 'reg_alpha':0.04, 'reg_lambda':0.073,
         'bagging_freq':2, 'min_child_weight':40}

N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(params, new_categorical_feats, N_Folds, SEED = 1989)
# Out:
# ============================== 1 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12158	training's macroF1: 0.545008	valid_1's multi_logloss: 1.07664	valid_1's macroF1: 0.435592
# Early stopping, best iteration is:
# [118]	training's multi_logloss: 1.29556	training's macroF1: 0.512187	valid_1's multi_logloss: 1.26386	valid_1's macroF1: 0.449068
# ******************** Execution ended in 00h 00m 13.61s ********************
# ============================== 2 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12619	training's macroF1: 0.544184	valid_1's multi_logloss: 1.0905	valid_1's macroF1: 0.430864
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 1.36399	training's macroF1: 0.497909	valid_1's multi_logloss: 1.3578	valid_1's macroF1: 0.461564
# ******************** Execution ended in 00h 00m 10.50s ********************
# ============================== 3 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11749	training's macroF1: 0.539664	valid_1's multi_logloss: 1.13193	valid_1's macroF1: 0.384034
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.38076	training's macroF1: 0.483748	valid_1's multi_logloss: 1.37995	valid_1's macroF1: 0.386236
# ******************** Execution ended in 00h 00m 10.04s ********************
# ============================== 4 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11834	training's macroF1: 0.55164	valid_1's multi_logloss: 1.11585	valid_1's macroF1: 0.43359
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.37274	training's macroF1: 0.493364	valid_1's multi_logloss: 1.36941	valid_1's macroF1: 0.470899
# ******************** Execution ended in 00h 00m 10.13s ********************
# ============================== 5 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11823	training's macroF1: 0.540643	valid_1's multi_logloss: 1.1259	valid_1's macroF1: 0.387796
# Early stopping, best iteration is:
# [156]	training's multi_logloss: 1.2687	training's macroF1: 0.509007	valid_1's multi_logloss: 1.25572	valid_1's macroF1: 0.412207
# ******************** Execution ended in 00h 00m 17.95s ********************
# ============================== 6 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11996	training's macroF1: 0.548423	valid_1's multi_logloss: 1.10718	valid_1's macroF1: 0.406935
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.37733	training's macroF1: 0.485254	valid_1's multi_logloss: 1.37493	valid_1's macroF1: 0.41856
# ******************** Execution ended in 00h 00m 09.23s ********************
# ============================== 7 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11911	training's macroF1: 0.53899	valid_1's multi_logloss: 1.146	valid_1's macroF1: 0.401689
# Early stopping, best iteration is:
# [68]	training's multi_logloss: 1.32916	training's macroF1: 0.503818	valid_1's multi_logloss: 1.32494	valid_1's macroF1: 0.429198
# ******************** Execution ended in 00h 00m 11.21s ********************
# ============================== 8 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11828	training's macroF1: 0.552678	valid_1's multi_logloss: 1.11865	valid_1's macroF1: 0.394172
# Early stopping, best iteration is:
# [188]	training's multi_logloss: 1.25054	training's macroF1: 0.517934	valid_1's multi_logloss: 1.2359	valid_1's macroF1: 0.410159
# ******************** Execution ended in 00h 00m 16.77s ********************
# ============================== 9 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12013	training's macroF1: 0.543074	valid_1's multi_logloss: 1.10903	valid_1's macroF1: 0.390797
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.36908	training's macroF1: 0.491311	valid_1's multi_logloss: 1.36477	valid_1's macroF1: 0.429836
# ******************** Execution ended in 00h 00m 10.29s ********************
# ============================== 10 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12005	training's macroF1: 0.537974	valid_1's multi_logloss: 1.13896	valid_1's macroF1: 0.405175
# [1000]	training's multi_logloss: 1.00125	training's macroF1: 0.580223	valid_1's multi_logloss: 1.06825	valid_1's macroF1: 0.434245
# [1500]	training's multi_logloss: 0.92341	training's macroF1: 0.618069	valid_1's multi_logloss: 1.03681	valid_1's macroF1: 0.440041
# Early stopping, best iteration is:
# [1034]	training's multi_logloss: 0.995021	training's macroF1: 0.583178	valid_1's multi_logloss: 1.06522	valid_1's macroF1: 0.445896
# ******************** Execution ended in 00h 00m 49.66s ********************

# %%
fig, ax = plt.subplots(1,2,figsize = (20, 20))
feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending = False).reset_index()

num_features = 50
sns.barplot(x = feat_importance_df_shap.shap_values[:num_features], y=feat_importance_df_shap.feature[:num_features], ax=ax[0])
ax[0].set_title('Feature importance based on shap values')

feat_importance_df = feat_importance_df.groupby('feature').mean().sort_values('feat_imp', ascending = False).reset_index()

num_features = 50
sns.barplot(x = feat_importance_df.shap_values[:num_features], y = feat_importance_df.feature[:num_features], ax = ax[1])
ax[1].set_title('Feature importance based on feature importance from lgbm')
plt.show()

# %%
submission['Target'] = np.array(predicts_result).mean(axis = 0).round().astype(int)
submission.to_csv('submission_with_new_feature_set.csv', index = False)
